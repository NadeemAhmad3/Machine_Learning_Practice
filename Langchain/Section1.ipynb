# %%
pip install langchain-google-genai langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 8.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 40.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 3.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.35.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-adk 1.25.1 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.
# google-colab 1.0.0 requires google-auth==2.47.0, but you have google-auth 2.49.2 which is incompatible.
# ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.globals import set_llm_cache
from langchain_community.cache import SQLiteCache
from langchain_core.messages import SystemMessage, HumanMessage
import os
print("All imports done")
# Out:
# All imports done

# %%
set_llm_cache(SQLiteCache(database_path=".langchain_cache.db"))
llm=ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0,
    api_key="Your_API_Key"
)
message=[
    SystemMessage(content="You are a Generative AI instructor who is instructing 8 semester students"),
    HumanMessage(content="Why we study Generative AI in 2026?")
]
response=llm.invoke(message)
print(response.content)
if response.usage_metadata:
    print(f"Input Tokens: {response.usage_metadata.get('input_tokens')}")
    print(f"Output Tokens: {response.usage_metadata.get('output_tokens')}")
# Out:
# Alright class, that's an excellent question, and it gets right to the heart of why we're here. "Why study Generative AI in 2026?" The short answer is: **because it's no longer a niche technology; it's a fundamental shift that will define the next decade, and your careers.**
#
# Let's break down the critical reasons:
#
# 1.  **Ubiquity and Integration Across Every Sector:**
#     *   **It's Everywhere, Already:** By 2026, Generative AI won't be a novelty. It will be deeply embedded in almost every industry – from marketing and design to software development, healthcare, finance, education, and even scientific research.
#     *   **Examples:** Think about how word processors or the internet became indispensable. Generative AI is on a similar trajectory. You'll see it generating marketing copy, designing product prototypes, writing initial code, synthesizing research papers, creating personalized learning content, and even assisting in drug discovery.
#
# ...
